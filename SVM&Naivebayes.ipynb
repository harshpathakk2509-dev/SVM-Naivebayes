# %% [markdown]
# 📘 Theoretical Questions & Answers
# ----
# ---
# Q1. What is a Support Vector Machine (SVM)?
# Ans: SVM is a supervised machine learning algorithm used for classification and regression tasks. It finds the optimal hyperplane that maximizes the margin between different classes in the dataset.
#
# Q2. What is the difference between Hard Margin and Soft Margin SVM?
# Ans:
#
# Hard Margin SVM: Assumes data is perfectly linearly separable and no misclassification is allowed.
#
# Soft Margin SVM: Allows some misclassification by introducing slack variables, making it more robust to noisy data.
#
# Q3. What is the mathematical intuition behind SVM?
# Ans: SVM maximizes the margin between classes by solving an optimization problem:
#
# min
# ⁡
# 1
# 2
# ∣
# ∣
# 𝑤
# ∣
# ∣
# 2
# subject to
# 𝑦
# 𝑖
# (
# 𝑤
# ⋅
# 𝑥
# 𝑖
# +
# 𝑏
# )
# ≥
# 1
# This ensures the hyperplane separates classes with maximum margin.
#
# Q4. What is the role of Lagrange Multipliers in SVM?
# Ans: Lagrange multipliers are used in the optimization process to handle constraints. They help transform the constrained optimization problem into an unconstrained one using the dual formulation.
#
# Q5. What are Support Vectors in SVM?
# Ans: Support vectors are the data points closest to the decision boundary. They directly influence the position and orientation of the hyperplane.
#
# Q6. What is a Support Vector Classifier (SVC)?
# Ans: SVC is the classification implementation of SVM. It separates data into categories using the optimal hyperplane.
#
# Q7. What is a Support Vector Regressor (SVR)?
# Ans: SVR is the regression version of SVM. It tries to fit the best line within a margin of tolerance, predicting continuous values.
#
# Q8. What is the Kernel Trick in SVM?
# Ans: The kernel trick allows SVM to operate in higher-dimensional spaces without explicitly computing transformations. It helps classify non-linear data using functions like polynomial or RBF kernels.
#
# Q9. Compare Linear Kernel, Polynomial Kernel, and RBF Kernel.
# Ans:
#
# Linear Kernel: Best for linearly separable data.
#
# Polynomial Kernel: Captures complex relationships with polynomial functions.
#
# RBF Kernel: Maps data into infinite dimensions, effective for non-linear problems.
#
# Q10. What is the effect of the C parameter in SVM?
# Ans: The C parameter controls the trade-off between maximizing margin and minimizing classification error.
#
# High C → less tolerance for misclassification.
#
# Low C → wider margin, more tolerance for errors.
#
# Q11. What is the role of the Gamma parameter in RBF Kernel SVM?
# Ans: Gamma defines how far the influence of a single training example reaches.
#
# High Gamma → narrow influence, risk of overfitting.
#
# Low Gamma → broad influence, risk of underfitting.
#
# Q12. What is the Naïve Bayes classifier, and why is it called "Naïve"?
# Ans: Naïve Bayes is a probabilistic classifier based on Bayes’ theorem. It is called "Naïve" because it assumes independence among features, which is rarely true in real-world data.
#
# Q13. What is Bayes' Theorem?
# Ans:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# It calculates the probability of event A given event B.
#
# Q14. Explain the differences between Gaussian Naïve Bayes, Multinomial Naïve Bayes, and Bernoulli Naïve Bayes.
# Ans:
#
# Gaussian NB: Assumes features follow a normal distribution.
#
# Multinomial NB: Works with discrete counts (e.g., word frequencies).
#
# Bernoulli NB: Works with binary features (e.g., presence/absence of a word).
#
# Q15. When should you use Gaussian Naïve Bayes over other variants?
# Ans: Use Gaussian NB when features are continuous and approximately normally distributed.
#
# Q16. What are the key assumptions made by Naïve Bayes?
# Ans:
#
# Features are independent.
#
# Each feature contributes equally to the outcome.
#
# Probabilities can be estimated accurately from training data.
#
# Q17. What are the advantages and disadvantages of Naïve Bayes?
# Ans:
#
# Advantages: Fast, works well with small datasets, effective for text classification.
#
# Disadvantages: Assumes independence, may perform poorly if features are highly correlated.
#
# Q18. Why is Naïve Bayes a good choice for text classification?
# Ans: Because text data often involves word frequencies, which fit well with the independence assumption. It is efficient and performs well in spam detection and sentiment analysis.
#
# Q19. Compare SVM and Naïve Bayes for classification tasks.
# Ans:
#
# SVM: Works well with high-dimensional data, robust to overfitting, but computationally expensive.
#
# Naïve Bayes: Simple, fast, effective for text data, but weaker when features are correlated.
#
# Q20. How does Laplace Smoothing help in Naïve Bayes?
# Ans: Laplace smoothing avoids zero probability issues by adding a small constant to frequency counts. This ensures unseen features don’t make the probability zero.

# %% [markdown]
# 🖥️ Practical Questions & Answers
# ----
# ---
# Q21. Train an SVM Classifier on the Iris dataset and evaluate accuracy.

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

iris = datasets.load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = SVC(kernel='linear')
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# Q22. Train two SVM classifiers with Linear and RBF kernels on the Wine dataset, then compare accuracies.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

wine = load_wine()
X, y = wine.data, wine.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

linear_svm = SVC(kernel='linear')
rbf_svm = SVC(kernel='rbf')

linear_svm.fit(X_train, y_train)
rbf_svm.fit(X_train, y_train)

print("Linear Kernel Accuracy:", accuracy_score(y_test, linear_svm.predict(X_test)))
print("RBF Kernel Accuracy:", accuracy_score(y_test, rbf_svm.predict(X_test)))
# Out:
# Linear Kernel Accuracy: 0.9814814814814815
# RBF Kernel Accuracy: 0.7592592592592593

# %% [markdown]
# Q23. Train an SVR on a housing dataset and evaluate using MSE

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
X, y = housing.data, housing.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)

y_pred = svr.predict(X_test)
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MSE: 1.3489971413208723

# %% [markdown]
# Q24. Train an SVM Classifier with a Polynomial Kernel and visualize the decision boundary.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.svm import SVC

X, y = make_classification(n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1, random_state=42)

model = SVC(kernel='poly', degree=3)
model.fit(X, y)

# Plot decision boundary
plt.scatter(X[:,0], X[:,1], c=y, cmap='coolwarm')
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 100),
                     np.linspace(ylim[0], ylim[1], 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3, cmap='coolwarm')
plt.show()

# %% [markdown]
# Q25. Train a Gaussian Naïve Bayes classifier on the Breast Cancer dataset and evaluate accuracy.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9415204678362573

# %% [markdown]
# Q26. Train a Multinomial Naïve Bayes classifier for text classification using the 20 Newsgroups dataset.

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

data = fetch_20newsgroups(subset='all')
X, y = data.data, data.target

vectorizer = CountVectorizer()
X_vec = vectorizer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.3, random_state=42)

mnb = MultinomialNB()
mnb.fit(X_train, y_train)

y_pred = mnb.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8443579766536965
